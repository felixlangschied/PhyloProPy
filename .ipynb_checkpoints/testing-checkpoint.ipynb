# %%
from PhyloProPy.PhyloProfile import PhyloProfile

size = 'small'

if size == 'small':
    path  = 'PhyloProPy/data/small.phyloprofile'
    pp = PhyloProfile(path=path, style='fasf')

pp.display()

pp.write('/home/felixl/Documents/tmp/pptest.phyloprofile')
# Out:
# 2024-03-21 14:41:47 - INFO - Reading NCBI Taxonomy
# 2024-03-21 14:41:47 - INFO - Initializing PhyloProfile matrix
# 2024-03-21 14:41:47 - INFO - Loading PhyloProfile matrix
#               ncbi118141  ncbi7165  ncbi8187  ncbi29144  ncbi224911  ncbi8040  \
# rdh13            0.68599   0.71402   0.99928    0.99970     0.65158   0.99973
# ddit4            0.99487   0.88312   0.99235    0.95149     0.00000   0.93983
# LOC115172565     0.97927   0.77716   0.97378    0.98239     0.00000   0.00000
# hgsnat           0.92365   0.45101   0.91396    0.93676     0.00000   0.92983
# LOC115159618     0.00000   0.00000   0.00000    0.00000     0.00000   0.00000
# LOC115168537     0.00000   0.00000   0.00000    0.64673     0.00000   0.88527
# LOC115151918     0.99568   0.00000   0.83831    0.82055     0.00000   0.86610
# LOC115163766     0.85170   0.00000   0.88307    0.87017     0.06088   0.98618
# LOC115156921     0.00000   0.99034   0.00000    0.00000     0.00000   0.99583
# ...

# %%
pp.to_binary()
pp.display()
